# %% [markdown]
# # Find alternative secondary structures for 11ntR variants
# Copyright 2023 John Shin under GPL-3.0
#
# Supporting Figures come from this document.

# %%
from tqdm import tqdm
import re

import numpy as np

# %%
def populateSeqDictFold(filename,seq_dict):
    with open(filename,'r') as f:
        for line in f:
            if line.startswith('>'):

                seq_id,scaffold,seq = line.split('::')
                seq_id = seq_id[1:]
                scaffold = scaffold[3:]
                seq = seq.rstrip()
                
                seq_dict[seq_id] = seq_dict.get(seq_id,{})

                seq_dict[seq_id]['seq'] = seq_dict[seq_id].get('seq',seq)
                
                seq_dict[seq_id][scaffold] = seq_dict[seq_id].get(scaffold,{})
                
            elif line.lower().startswith(('a','u','c','g')):
                seq_dict[seq_id][scaffold]['full_seq'] = line.rstrip()
            
            elif line.startswith(' free energy'):

                free_energy = re.search(r'-\d+.\d+',line).group(0)

                if free_energy:
                    seq_dict[seq_id][scaffold]['dG_ensemble'] = np.float64(free_energy)
                else:
                    print(f"oh no, issue with {seq_id}::{scaffold}")
            elif line.startswith(' frequency'):

                frequency = re.search(r'\d+.\d+',line).group(0)

                if frequency:
                    seq_dict[seq_id][scaffold]['MFE_freq'] = np.float64(frequency)
                else:
                    print(f"oh no, issue with {seq_id}::{scaffold}")

# %%
def freqFromDG(dG,dG_ensemble):
    '''Assumes T=37 C and uses R = 1.98717 kcal/mol'''
    return np.exp(-(dG-dG_ensemble)/(1.98717/1000*(37+273.15)))

def populateSeqDictSubopt(filename,seq_dict):
    with open(filename,'r') as f:
                
        for line in f:
            if line.startswith('>'):
                seq_id,scaffold,seq = line.split('::')
                seq_id = seq_id[1:]
                scaffold = scaffold[3:]
                seq = seq.split(' ')[0]
                
                seq_dict[seq_id] = seq_dict.get(seq_id,{})

                seq_dict[seq_id]['seq'] = seq_dict[seq_id].get('seq',seq)
                
                seq_dict[seq_id][scaffold] = seq_dict[seq_id].get(scaffold,{})
                
                alt_structs = 0
                cum_struct_freq = 0
            
            elif re.search(r'^[.()]+',line) and (cum_struct_freq < 0.95):

                free_energy = re.search(r'-\d+.\d+',line)

                if free_energy:
                    free_energy = np.float64(free_energy.group(0))
                    structure = re.search(r'[(.)]+',line).group(0)
                    frequency = freqFromDG(free_energy,
                                   seq_dict[seq_id][scaffold]['dG_ensemble'])
                    
                    seq_dict[seq_id][scaffold][f"alt{alt_structs}"] =\
                        seq_dict[seq_id][scaffold].get(f"alt{alt_structs}",{})
                    
                    seq_dict[seq_id][scaffold][f"alt{alt_structs}"]['free_energy'] = \
                        free_energy
                    seq_dict[seq_id][scaffold][f"alt{alt_structs}"]['structure'] = \
                        structure
                    seq_dict[seq_id][scaffold][f"alt{alt_structs}"]['frequency'] = \
                        frequency
                    
                    cum_struct_freq += frequency
                    
                else:
                    print(f"oh no, issue with {seq_id}::{scaffold}::alt{alt_structs}")
                
                alt_structs += 1

# %%
data_path = 'Data/structures/'

# %%
all_seq_info = {}

populateSeqDictFold(data_path+'all_muts_13854_fold.fasta',all_seq_info)
populateSeqDictFold(data_path+'all_muts_14007_fold.fasta',all_seq_info)
populateSeqDictFold(data_path+'all_muts_14073_fold.fasta',all_seq_info)
populateSeqDictFold(data_path+'all_muts_35311_A_fold.fasta',all_seq_info)
populateSeqDictFold(data_path+'all_muts_35600_fold.fasta',all_seq_info)

# %%
populateSeqDictSubopt(data_path+'all_muts_13854_subopt.fasta',all_seq_info)
populateSeqDictSubopt(data_path+'all_muts_14007_subopt.fasta',all_seq_info)
populateSeqDictSubopt(data_path+'all_muts_14073_subopt.fasta',all_seq_info)
populateSeqDictSubopt(data_path+'all_muts_35311_A_subopt.fasta',all_seq_info)
populateSeqDictSubopt(data_path+'all_muts_35600_subopt.fasta',all_seq_info)

# %%
scaffold_params = ((11,21),(25,-12))
receptor_params = ((6,11),(-12,-6))

# %%
# for k,v in all_seq_info['wt'].items():
#     if k == 'seq':
#         continue
#     print(k)
#     for kk,vv in v.items():
#         if kk.startswith('alt'):
#             print(vv['structure'][slice(*receptor_params[0])],
#                   vv['structure'][slice(*receptor_params[1])],
#                   vv['frequency'])

# %%
# wt_counts_dict= {
#       '13854': ('9,9', 0.9522239788764616),
#       '14007': ('10,10', 0.9522239788764599),
#       '14073': ('10,10', 0.9329280855679988),
#       '35311_A': ('10,10', 0.9524190366331612),
#       '35600': ('10,10', 0.9524190366331597)}

# wt_receptors=('(..(())...)',
#               '(.((()).).)',
#               '(..(())...)',
#               '...(())....')

# %%
# all_seq_structure = {}
# alt_structures = {}
# alt_receptors = {}
# for receptor_name,receptor_dict in all_seq_info.items():
#     for receptor_k, receptor_v in receptor_dict.items():
#         if receptor_k == 'seq':
#             all_seq_structure[receptor_name] = all_seq_structure.get(receptor_name,{})
#         else:
#             scaffold = receptor_k
#             scaffold_counts_dict = {}
#             receptor_counts_dict = {}
#             for scaffold_k,scaffold_v in receptor_v.items():
#                 if scaffold_k.startswith('alt'):
#                     scaffold_l = scaffold_v['structure'][slice(*scaffold_params[0])].count('(')
#                     scaffold_r = scaffold_v['structure'][slice(*scaffold_params[1])].count(')')
                    
#                     receptor_l = scaffold_v['structure'][slice(
#                                                             *receptor_params[0])]
#                     receptor_r = scaffold_v['structure'][slice(
#                                                             *receptor_params[1])]
                    
#                     freq = scaffold_v['frequency']

#                     scaffold_counts_dict[f"{scaffold_l},{scaffold_r}"] = \
#                                 scaffold_counts_dict.get(f"{scaffold_l},{scaffold_r}",0) + freq
                    
#                     receptor_counts_dict[f"{receptor_l}{receptor_r}"] = \
#                                 receptor_counts_dict.get(f"{receptor_l}{receptor_r}",0) + freq
                    
#             all_seq_structure[receptor_name][scaffold] = scaffold_counts_dict            
            
#             if scaffold_counts_dict.get(wt_counts_dict[scaffold][0]) \
#                                 < wt_counts_dict[scaffold][1]*0.9:
#                 if scaffold == '14073':
#                     if scaffold_counts_dict.get('10,10',0) + scaffold_counts_dict.get('9,9',0) < 0.85:
#                         continue
#                 else:
#                     alt_structures[receptor_name] = alt_structures.get(receptor_name,{})
#                     alt_structures[receptor_name][scaffold] = scaffold_counts_dict
            
#             if sum([receptor_counts_dict.get(idx,0) for idx in wt_receptors]) < 0.75:
#                 alt_receptors[receptor_name] = alt_receptors.get(receptor_name,{})
#                 alt_receptors[receptor_name][scaffold] = receptor_counts_dict
#                 alt_receptors[receptor_name][scaffold]['total'] = sum([receptor_counts_dict.get(idx,0) for idx in wt_receptors])

# %% [markdown]
# ## Synergistic Mutants

# %%
import pandas as pd

# %%
syn_df = pd.read_csv('../refit_bootstrapped/Figures/GAAA_coop.csv').set_index('seq')
syn_df['muts'] = syn_df[['first_loc','first_res','second_loc','second_res']].apply(
                            (lambda s: ''.join([str(x) for x in s])), axis=1)
# syn_df = syn_df[syn_df['coop']=='S'][['muts','dddG']]
# syn_df.head()

# %%
for row in syn_df.iterrows():
    display(all_seq_info[row[1]['muts']])
    break
# Out:
# {'seq': 'UAUGG_AAUAAG',
#  '13854': {'full_seq': 'cuaggaUAUGGaacugagucgGGAAcgacugaguuAAUAAGuccuag',
#   'dG_ensemble': -21.63,
#   'MFE_freq': 0.36245,
#   'alt0': {'free_energy': -21.0,
#    'structure': '(((((((.((.((((.(((((....))))).))))..)).)))))))',
#    'frequency': 0.3598043111443066},
#   'alt1': {'free_energy': -20.9,
#    'structure': '(((((((....((((.(((((....))))).)))).....)))))))',
#    'frequency': 0.30591495325738},
#   'alt2': {'free_energy': -19.8,
#    'structure': '(((((((.((..(((.(((((....))))).)))...)).)))))))',
#    'frequency': 0.05134267383248952},
#   'alt3': {'free_energy': -19.5,
#    'structure': '(((((((..(.((((.(((((....))))).))))..)..)))))))',
#    'frequency': 0.03155596836837083},
#   'alt4': {'free_energy': -19.4,
#    'structure': '.((((((.((.((((.(((((....))))).))))..)).)))))).',
#    'frequency': 0.026829702394893813},
#   'alt5': {'free_energy': -19.3,
#    'structure': '((((((.....((((.(((((....))))).))))......))))))',
#    'frequency': 0.0228113085358546},
#   'alt6': {'free_energy': -19.3,
#    'structure': '.((((((....((((.(((((....))))).)))).....)))))).',
#    'frequency': 0.0228113085358546},
#   'alt7': {'free_energy': -19.2,
#    'structure': '(((((((((..((((.(((((....))))).)))).))..)))))))',
#    'frequency': 0.019394765900086278},
#   'alt8': {'free_energy': -19.1,
#    'structure': '(((((((((..((((.(((((....))))).)))).)))..))))))',
#    'frequency': 0.016489932777328926},
#   'alt9': {'free_energy': -19.1,
#    'structure': '(((((((.(..((((.(((((....))))).))))...).)))))))',
#    'frequency': 0.016489932777328926},
#   'alt10': {'free_energy': -19.0,
#    'structure': '((((((..((.((((.(((((....))))).))))..))..))))))',
#    'frequency': 0.01402016834859634},
#   'alt11': {'free_energy': -19.0,
#    'structure': '(((((((.....(((.(((((....))))).)))......)))))))',
#    'frequency': 0.01402016834859634},
#   'alt12': {'free_energy': -18.5,
#    'structure': '(((((((.(..((((.(((((....))))).))))....))))))))',
#    'frequency': 0.006229094864982935},
#   'alt13': {'free_energy': -18.3,
#    'structure': '(((((((..(..(((.(((((....))))).)))...)..)))))))',
#    'frequency': 0.004502913781807967},
#   'alt14': {'free_energy': -18.2,
#    'structure': '(((((((.(..((((.(((((....))))).)))).)...)))))))',
#    'frequency': 0.003828494035279412},
#   'alt15': {'free_energy': -18.2,
#    'structure': '.((((((.((..(((.(((((....))))).)))...)).)))))).',
#    'frequency': 0.003828494035279412},
#   'alt16': {'free_energy': -18.1,
#    'structure': '(((((((.((...((.(((((....))))).))....)).)))))))',
#    'frequency': 0.003255084882456944},
#   'alt17': {'free_energy': -18.0,
#    'structure': '(((((((((...(((.(((((....))))).)))..))..)))))))',
#    'frequency': 0.002767557555101786}},
#  '14007': {'full_seq': 'cuaggaUAUGGaagccggucgGGAAcgaccaggcuuAAUAAGuccuag',
#   'dG_ensemble': -25.22,
#   'MFE_freq': 0.362867,
#   'alt0': {'free_energy': -24.6,
#    'structure': '(((((((.((.((((((((((....))))).)))))..)).)))))))',
#    'frequency': 0.36568986857469793},
#   'alt1': {'free_energy': -24.5,
#    'structure': '(((((((....((((((((((....))))).))))).....)))))))',
#    'frequency': 0.3109190067677051},
#   'alt2': {'free_energy': -23.4,
#    'structure': '(((((((.((..(((((((((....))))).))))...)).)))))))',
#    'frequency': 0.05218251995470473},
#   'alt3': {'free_energy': -23.1,
#    'structure': '(((((((..(.((((((((((....))))).)))))..)..)))))))',
#    'frequency': 0.03207215024377133},
#   'alt4': {'free_energy': -23.0,
#    'structure': '.((((((.((.((((((((((....))))).)))))..)).)))))).',
#    'frequency': 0.027268573607368316},
#   'alt5': {'free_energy': -22.9,
#    'structure': '((((((.....((((((((((....))))).)))))......))))))',
#    'frequency': 0.02318444821843125},
#   'alt6': {'free_energy': -22.9,
#    'structure': '.((((((....((((((((((....))))).))))).....)))))).',
#    'frequency': 0.02318444821843125},
#   'alt7': {'free_energy': -22.8,
#    'structure': '(((((((((..((((((((((....))))).))))).))..)))))))',
#    'frequency': 0.019712018931854904},
#   'alt8': {'free_energy': -22.7,
#    'structure': '(((((((((..((((((((((....))))).))))).)))..))))))',
#    'frequency': 0.01675966952971959},
#   'alt9': {'free_energy': -22.7,
#    'structure': '(((((((.(..((((((((((....))))).)))))...).)))))))',
#    'frequency': 0.01675966952971959},
#   'alt10': {'free_energy': -22.6,
#    'structure': '((((((..((.((((((((((....))))).)))))..))..))))))',
#    'frequency': 0.014249505528401072},
#   'alt11': {'free_energy': -22.6,
#    'structure': '(((((((.....(((((((((....))))).))))......)))))))',
#    'frequency': 0.014249505528401072},
#   'alt12': {'free_energy': -22.1,
#    'structure': '(((((((.(..((((((((((....))))).)))))....))))))))',
#    'frequency': 0.006330988295471896},
#   'alt13': {'free_energy': -21.9,
#    'structure': '(((((((..(..(((((((((....))))).))))...)..)))))))',
#    'frequency': 0.0045765709249995954},
#   'alt14': {'free_energy': -21.8,
#    'structure': '(((((((.(..((((((((((....))))).))))).)...)))))))',
#    'frequency': 0.00389111924798152},
#   'alt15': {'free_energy': -21.8,
#    'structure': '(((((((.((...((((((((....))))).)))....)).)))))))',
#    'frequency': 0.00389111924798152},
#   'alt16': {'free_energy': -21.8,
#    'structure': '.((((((.((..(((((((((....))))).))))...)).)))))).',
#    'frequency': 0.00389111924798152},
#   'alt17': {'free_energy': -21.6,
#    'structure': '(((((((.((.(((((.((((....))))..)))))..)).)))))))',
#    'frequency': 0.002812828327096322},
#   'alt18': {'free_energy': -21.6,
#    'structure': '(((((((((...(((((((((....))))).))))..))..)))))))',
#    'frequency': 0.002812828327096322}},
#  '14073': {'full_seq': 'cuaggaUAUGGaagccggucgGGAAcgaccguggcuuAAUAAGuccuag',
#   'dG_ensemble': -23.98,
#   'MFE_freq': 0.280614,
#   'alt0': {'free_energy': -23.2,
#    'structure': '(((((((.((.((((((((((....)))))..)))))..)).)))))))',
#    'frequency': 0.2820771309185411},
#   'alt1': {'free_energy': -23.1,
#    'structure': '(((((((....((((((((((....)))))..))))).....)))))))',
#    'frequency': 0.23982928955321192},
#   'alt2': {'free_energy': -22.3,
#    'structure': '(((((((.((.((((((((((....))))))..))))..)).)))))))',
#    'frequency': 0.06549029809843171},
#   'alt3': {'free_energy': -22.2,
#    'structure': '(((((((....((((((((((....))))))..)))).....)))))))',
#    'frequency': 0.05568154927848654},
#   'alt4': {'free_energy': -22.0,
#    'structure': '(((((((.((..(((((((((....)))))..))))...)).)))))))',
#    'frequency': 0.04025130794652032},
#   'alt5': {'free_energy': -21.7,
#    'structure': '(((((((..(.((((((((((....)))))..)))))..)..)))))))',
#    'frequency': 0.02473905049218899},
#   'alt6': {'free_energy': -21.6,
#    'structure': '.((((((.((.((((((((((....)))))..)))))..)).)))))).',
#    'frequency': 0.021033782088049215},
#   'alt7': {'free_energy': -21.5,
#    'structure': '((((((.....((((((((((....)))))..)))))......))))))',
#    'frequency': 0.017883466831810114},
#   'alt8': {'free_energy': -21.5,
#    'structure': '.((((((....((((((((((....)))))..))))).....)))))).',
#    'frequency': 0.017883466831810114},
#   'alt9': {'free_energy': -21.4,
#    'structure': '(((((((((..((((((((((....)))))..))))).))..)))))))',
#    'frequency': 0.015204987129070037},
#   'alt10': {'free_energy': -21.3,
#    'structure': '(((((((((..((((((((((....)))))..))))).)))..))))))',
#    'frequency': 0.012927674246246053},
#   'alt11': {'free_energy': -21.3,
#    'structure': '(((((((.(..((((((((((....)))))..)))))...).)))))))',
#    'frequency': 0.012927674246246053},
#   'alt12': {'free_energy': -21.2,
#    'structure': '((((((..((.((((((((((....)))))..)))))..))..))))))',
#    'frequency': 0.010991443793959589},
#   'alt13': {'free_energy': -21.2,
#    'structure': '(((((((.....(((((((((....)))))..))))......)))))))',
#    'frequency': 0.010991443793959589},
#   'alt14': {'free_energy': -21.1,
#    'structure': '(((((((.((..(((((((((....))))))..)))...)).)))))))',
#    'frequency': 0.009345210466674239},
#   'alt15': {'free_energy': -20.8,
#    'structure': '(((((((..(.((((((((((....))))))..))))..)..)))))))',
#    'frequency': 0.005743704872953652},
#   'alt16': {'free_energy': -20.8,
#    'structure': '(((((((.((.((((((((((....)))))).).)))..)).)))))))',
#    'frequency': 0.005743704872953652},
#   'alt17': {'free_energy': -20.8,
#    'structure': '(((((((.((.((((((((((....))))..))))))..)).)))))))',
#    'frequency': 0.005743704872953652},
#   'alt18': {'free_energy': -20.7,
#    'structure': '(((((((....((((((((((....)))))).).))).....)))))))',
#    'frequency': 0.004883446788465769},
#   'alt19': {'free_energy': -20.7,
#    'structure': '(((((((....((((((((((....))))..)))))).....)))))))',
#    'frequency': 0.004883446788465769},
#   'alt20': {'free_energy': -20.7,
#    'structure': '(((((((.(..((((((((((....)))))..)))))....))))))))',
#    'frequency': 0.004883446788465769},
#   'alt21': {'free_energy': -20.7,
#    'structure': '.((((((.((.((((((((((....))))))..))))..)).)))))).',
#    'frequency': 0.004883446788465769},
#   'alt22': {'free_energy': -20.6,
#    'structure': '((((((.....((((((((((....))))))..))))......))))))',
#    'frequency': 0.004152033062853579},
#   'alt23': {'free_energy': -20.6,
#    'structure': '.((((((....((((((((((....))))))..)))).....)))))).',
#    'frequency': 0.004152033062853579},
#   'alt24': {'free_energy': -20.5,
#    'structure': '(((((((..(..(((((((((....)))))..))))...)..)))))))',
#    'frequency': 0.003530166151445923},
#   'alt25': {'free_energy': -20.5,
#    'structure': '(((((((((..((((((((((....))))))..)))).))..)))))))',
#    'frequency': 0.003530166151445923},
#   'alt26': {'free_energy': -20.4,
#    'structure': '(((((((((..((((((((((....))))))..)))).)))..))))))',
#    'frequency': 0.003001438781474848},
#   'alt27': {'free_energy': -20.4,
#    'structure': '(((((((.(..((((((((((....)))))..))))).)...)))))))',
#    'frequency': 0.003001438781474848},
#   'alt28': {'free_energy': -20.4,
#    'structure': '(((((((.(..((((((((((....))))))..))))...).)))))))',
#    'frequency': 0.003001438781474848},
#   'alt29': {'free_energy': -20.4,
#    'structure': '(((((((.((...((((((((....)))))..)))....)).)))))))',
#    'frequency': 0.003001438781474848},
#   'alt30': {'free_energy': -20.4,
#    'structure': '(((((((.((.((((.(((((....)))))...))))..)).)))))))',
#    'frequency': 0.003001438781474848},
#   'alt31': {'free_energy': -20.4,
#    'structure': '(((((((.((.(((((.((((....))))...)))))..)).)))))))',
#    'frequency': 0.003001438781474848},
#   'alt32': {'free_energy': -20.4,
#    'structure': '.((((((.((..(((((((((....)))))..))))...)).)))))).',
#    'frequency': 0.003001438781474848},
#   'alt33': {'free_energy': -20.3,
#    'structure': '((((((..((.((((((((((....))))))..))))..))..))))))',
#    'frequency': 0.0025519010642746707},
#   'alt34': {'free_energy': -20.3,
#    'structure': '(((((((.....(((((((((....))))))..)))......)))))))',
#    'frequency': 0.0025519010642746707},
#   'alt35': {'free_energy': -20.3,
#    'structure': '(((((((....((((.(((((....)))))...)))).....)))))))',
#    'frequency': 0.0025519010642746707},
#   'alt36': {'free_energy': -20.3,
#    'structure': '(((((((....(((((.((((....))))...))))).....)))))))',
#    'frequency': 0.0025519010642746707},
#   'alt37': {'free_energy': -20.2,
#    'structure': '(((((((((...(((((((((....)))))..))))..))..)))))))',
#    'frequency': 0.00216969244285109}},
#  '35311_A': {'full_seq': 'cuaggaUAUGGagggaucuugGGAAcaagaucccuAAUAAGuccuag',
#   'dG_ensemble': -26.28,
#   'MFE_freq': 0.390398,
#   'alt0': {'free_energy': -25.7,
#    'structure': '(((((((.((.((((((((((....))))))))))..)).)))))))',
#    'frequency': 0.390210715300064},
#   'alt1': {'free_energy': -25.6,
#    'structure': '(((((((....((((((((((....)))))))))).....)))))))',
#    'frequency': 0.33176726635627324},
#   'alt2': {'free_energy': -24.2,
#    'structure': '(((((((..(.((((((((((....))))))))))..)..)))))))',
#    'frequency': 0.034222705530811755},
#   'alt3': {'free_energy': -24.1,
#    'structure': '.((((((.((.((((((((((....))))))))))..)).)))))).',
#    'frequency': 0.029097031465530495},
#   'alt4': {'free_energy': -24.0,
#    'structure': '((((((.....((((((((((....))))))))))......))))))',
#    'frequency': 0.02473905049218899},
#   'alt5': {'free_energy': -24.0,
#    'structure': '(((((((.((..(((((((((....)))))))))...)).)))))))',
#    'frequency': 0.02473905049218899},
#   'alt6': {'free_energy': -24.0,
#    'structure': '.((((((....((((((((((....)))))))))).....)))))).',
#    'frequency': 0.02473905049218899},
#   'alt7': {'free_energy': -23.9,
#    'structure': '(((((((((..((((((((((....)))))))))).))..)))))))',
#    'frequency': 0.021033782088049093},
#   'alt8': {'free_energy': -23.8,
#    'structure': '(((((((((..((((((((((....)))))))))).)))..))))))',
#    'frequency': 0.017883466831810114},
#   'alt9': {'free_energy': -23.8,
#    'structure': '(((((((.(..((((((((((....))))))))))...).)))))))',
#    'frequency': 0.017883466831810114},
#   'alt10': {'free_energy': -23.7,
#    'structure': '((((((..((.((((((((((....))))))))))..))..))))))',
#    'frequency': 0.015204987129070037},
#   'alt11': {'free_energy': -23.2,
#    'structure': '(((((((.....(((((((((....)))))))))......)))))))',
#    'frequency': 0.0067555042773294665},
#   'alt12': {'free_energy': -23.2,
#    'structure': '(((((((.(..((((((((((....))))))))))....))))))))',
#    'frequency': 0.0067555042773294665},
#   'alt13': {'free_energy': -22.9,
#    'structure': '(((((((.(..((((((((((....)))))))))).)...)))))))',
#    'frequency': 0.004152033062853554}},
#  '35600': {'full_seq': 'cuaggaUAUGGaaugcacaggGGAAccugugcauuAAUAAGuccuag',
#   'dG_ensemble': -25.92,
#   'MFE_freq': 0.365024,
#   'alt0': {'free_energy': -25.3,
#    'structure': '(((((((.((.((((((((((....))))))))))..)).)))))))',
#    'frequency': 0.36568986857469576},
#   'alt1': {'free_energy': -25.2,
#    'structure': '(((((((....((((((((((....)))))))))).....)))))))',
#    'frequency': 0.3109190067677033},
#   'alt2': {'free_energy': -24.1,
#    'structure': '(((((((.((..(((((((((....)))))))))...)).)))))))',
#    'frequency': 0.05218251995470473},
#   'alt3': {'free_energy': -23.8,
#    'structure': '(((((((..(.((((((((((....))))))))))..)..)))))))',
#    'frequency': 0.03207215024377114},
#   'alt4': {'free_energy': -23.7,
#    'structure': '.((((((.((.((((((((((....))))))))))..)).)))))).',
#    'frequency': 0.02726857360736816},
#   'alt5': {'free_energy': -23.6,
#    'structure': '((((((.....((((((((((....))))))))))......))))))',
#    'frequency': 0.02318444821843125},
#   'alt6': {'free_energy': -23.6,
#    'structure': '.((((((....((((((((((....)))))))))).....)))))).',
#    'frequency': 0.02318444821843125},
#   'alt7': {'free_energy': -23.5,
#    'structure': '(((((((((..((((((((((....)))))))))).))..)))))))',
#    'frequency': 0.019712018931854793},
#   'alt8': {'free_energy': -23.4,
#    'structure': '(((((((((..((((((((((....)))))))))).)))..))))))',
#    'frequency': 0.0167596695297195},
#   'alt9': {'free_energy': -23.4,
#    'structure': '(((((((.(..((((((((((....))))))))))...).)))))))',
#    'frequency': 0.0167596695297195},
#   'alt10': {'free_energy': -23.3,
#    'structure': '((((((..((.((((((((((....))))))))))..))..))))))',
#    'frequency': 0.014249505528400982},
#   'alt11': {'free_energy': -23.3,
#    'structure': '(((((((.....(((((((((....)))))))))......)))))))',
#    'frequency': 0.014249505528400982},
#   'alt12': {'free_energy': -22.8,
#    'structure': '(((((((.((...((((((((....))))))))....)).)))))))',
#    'frequency': 0.006330988295471862},
#   'alt13': {'free_energy': -22.8,
#    'structure': '(((((((.(..((((((((((....))))))))))....))))))))',
#    'frequency': 0.006330988295471862},
#   'alt14': {'free_energy': -22.6,
#    'structure': '(((((((..(..(((((((((....)))))))))...)..)))))))',
#    'frequency': 0.0045765709249995954},
#   'alt15': {'free_energy': -22.5,
#    'structure': '(((((((.(..((((((((((....)))))))))).)...)))))))',
#    'frequency': 0.0038911192479814997},
#   'alt16': {'free_energy': -22.5,
#    'structure': '.((((((.((..(((((((((....)))))))))...)).)))))).',
#    'frequency': 0.0038911192479814997},
#   'alt17': {'free_energy': -22.3,
#    'structure': '(((((((((...(((((((((....)))))))))..))..)))))))',
#    'frequency': 0.0028128283270963074}}}

# %%
def fold11ntR(seq,fold,verbose=False,pad=''):
    left = 0
    right = len(seq)-1
    
    lines = []
    
    finished = False
    seen = 0
    
    while not finished:
        
        if verbose:
            print(left,right,seen)
            print('\n'.join(lines[::-1]),'\n')
        
        
        if left == right:
            lines += [f"{pad}{seq[left]}"]
            left += 1
            seen += 1          
        elif fold[left] == '.':            
            if fold[right] == '.':
                lines += [f"{pad}{seq[left]} {seq[right]}"]
                left += 1
                right -= 1
                seen += 2
            else:
                lines += [f"{pad}{seq[left]} |"]
                left += 1
                seen += 1
                
        elif fold[left] == '(':            
            if fold[right] == '.':
                lines += [f"{pad}| {seq[right]}"]
                right -= 1
                seen += 1
            else:
                lines += [f"{pad}{seq[left]}-{seq[right]}"]
                left += 1
                right -= 1
                seen += 2
            
        if seen == len(seq):
            finished = True
            
            
    lines = lines[::-1]
    
    return '\n'.join(lines)
                   

def get11ntRFolds(d,verbose=False):
    
    scaffold_dicts = {}

    for k,v in d.items():        
        if k == 'seq':
            seq = v            
        else:
            scaffold = k
            fold_energies = {}
            fold_freqs = {}
            
            for kk,vv in v.items():
                tot_freq = 0
                if 'alt' in kk:
                    fold = ''.join([vv['structure'][slice(*i)] for i in receptor_params])
                    fold_energies[fold] = fold_energies.get(fold,0) + vv['free_energy']*vv['frequency']
                    fold_freqs[fold] = fold_freqs.get(fold,0) + vv['frequency']
                    
            for k in fold_energies.keys():
                fold_energies[k] = fold_energies[k]/fold_freqs[k]
                
            scaffold_dicts[scaffold] = fold_energies
    
    if verbose:
        return scaffold_dicts
    
    output = {}
    
    for k,v in scaffold_dicts.items():
        fold = sorted(v, key=v.get)[0]
        output[fold] = output.get(fold,{})
        output[fold].update({k:v[fold]})
        
    return output

# %%
print('Scaffold 1')
print(fold11ntR('cuaggaUAUGGaacugagucgGGAAcgacugaguuCCUAAGuccuag'.replace('_',''),
                '(((((((..((((((.(((((....))))).))))))...)))))))',pad='   '))

print('Scaffold 2')
print(fold11ntR('cuaggaUAUGGaaugcacaggGGAAccugugcauuCCUAAGuccuag'.replace('_',''),
                '(((((((..((((((((((((....))))))))))))...)))))))',pad='   '))

print('Scaffold 3')
print(fold11ntR('cuaggaUAUGGagggaucuugGGAAcaagaucccuCCUAAGuccuag'.replace('_',''),
                '(((((((..((((((((((((....))))))))))))...)))))))',pad='   '))

print('Scaffold 4')
print(fold11ntR('cuaggaUAUGGaagccggucgGGAAcgaccguggcuuCCUAAGuccuag'.replace('_',''),
                '(((((((..((((((((((((....)))))..)))))))...)))))))',pad='   '))

print('Scaffold 5')
print(fold11ntR('cuaggaUAUGGaagccggucgGGAAcgaccaggcuuCCUAAGuccuag'.replace('_',''),
                '(((((((..((((((((((((....))))).)))))))...)))))))',pad='   '))
# Out:
# Scaffold 1
#    G A
#    G A
#    g-c
#    c-g
#    u-a
#    g-c
#    a-u
#    g g
#    u-a
#    c-g
#    a-u
#    a-u
#    G-C
#    G-C
#    | U
#    U A
#    A A
#    U-G
#    a-u
#    g-c
#    g-c
#    a-u
#    u-a
#    c-g
# Scaffold 2
#    G A
#    G A
#    g-c
#    g-c
#    a-u
#    c-g
#    a-u
#    c-g
#    g-c
#    u-a
#    a-u
#    a-u
#    G-C
#    G-C
#    | U
#    U A
#    A A
#    U-G
#    a-u
#    g-c
#    g-c
#    a-u
#    u-a
#    c-g
# Scaffold 3
#    G A
#    G A
#    g-c
#    u-a
#    u-a
#    c-g
#    u-a
#    a-u
#    g-c
#    g-c
#    g-c
#    a-u
#    G-C
#    G-C
#    | U
#    U A
#    A A
#    U-G
#    a-u
#    g-c
#    g-c
#    a-u
#    u-a
#    c-g
# Scaffold 4
#    G A
#    G A
#    g-c
#    c-g
#    u-a
#    g-c
#    g-c
#    | g
#    | u
#    c-g
#    c-g
#    g-c
#    a-u
#    a-u
#    G-C
#    G-C
#    | U
#    U A
#    A A
#    U-G
#    a-u
#    g-c
#    g-c
#    a-u
#    u-a
#    c-g
# Scaffold 5
#    G A
#    G A
#    g-c
#    c-g
#    u-a
#    g-c
#    g-c
#    | a
#    c-g
#    c-g
#    g-c
#    a-u
#    a-u
#    G-C
#    G-C
#    | U
#    U A
#    A A
#    U-G
#    a-u
#    g-c
#    g-c
#    a-u
#    u-a
#    c-g

# %%
syn_df['dG_fold'] = [list(get11ntRFolds(all_seq_info[muts]).values())[0]['13854'] for muts in syn_df['muts']]
syn_df['Structure'] = [list(get11ntRFolds(all_seq_info[muts]).keys())[0] for muts in syn_df['muts']]

syn_df[['muts','dddG','dG_fold','Structure']].sort_values('dddG',ascending=False).to_csv('Figures/Supplement/Syn.csv')
